# %%
import os
from dotenv import load_dotenv
from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient
from azure.ai.projects.models import PromptAgentDefinition

# %%
load_dotenv("../.env")
# Out:
# True

# %%
project_client = AIProjectClient(
    endpoint=os.environ["PROJECT_ENDPOINT"],
    credential=DefaultAzureCredential(),
)
openai_client = project_client.get_openai_client()

# %%
agent = project_client.agents.create_version(
    agent_name="hello-world-agent",
    definition=PromptAgentDefinition(
        model=os.environ["MODEL_DEPLOYMENT_NAME"],
    ),
)
print(f"Agent created (id: {agent.id}, name: {agent.name}, version: {agent.version})")
# Out:
# Agent created (id: hello-world-agent:1, name: hello-world-agent, version: 1)

# %%
conversation = openai_client.conversations.create()
print(f"Created conversation (id: {conversation.id})")
# Out:
# Created conversation (id: conv_6cffa8ada9325b5e00mtlKEhVfKJdYoVT3h6dheGRmtTFVY0yO)

# %%
while True:
    # Get the user input
    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit"]:
        print("Exiting the chat.")
        break

    # Get the agent response
    response = openai_client.responses.create(
        conversation=conversation.id,
        input=user_input,
        extra_body={"agent": {"name": agent.name, "type": "agent_reference"}},
    )

    # Print the agent response
    print(f"Assistant: {response.output_text}")
# Out:
# Assistant: Choosing a hobby depends on your interests, lifestyle, and what you'd like to achieve. Here are some popular options:
#
# 1. **Reading**: Expands knowledge and imagination.
#
# 2. **Gardening**: Connects you with nature and provides relaxation.
#
# 3. **Cooking/Baking**: Allows creativity and the enjoyment of eating your creations.
#
# 4. **Photography**: Enhances creativity and captures life's moments.
#
# 5. **Painting/Drawing**: Offers a creative outlet and helps relieve stress.
#
# 6. **Music**: Playing an instrument or singing can be fulfilling and meditative.
#
# 7. **Hiking**: Provides exercise and time in nature.
#
# 8. **Writing**: Whether journaling, poetry, or stories, it's a great way to express yourself.
#
# 9. **Crafting**: Includes knitting, sewing, or DIY projects that can be both fun and productive.
#
# 10. **Learning a New Language**: Expands communication skills and cultural understanding.
#
# Consider what excites you or what skills you'd like to develop, and start from there!
# Assistant: Learning a new language is a rewarding hobby that can enhance both personal and professional aspects of life. Here’s why it could be a great choice:
#
# 1. **Cognitive Benefits**: Improves memory, problem-solving skills, and multitasking abilities. It can also delay the onset of age-related cognitive decline.
#
# 2. **Cultural Understanding**: Allows you to experience new cultures, traditions, and perspectives, enriching your worldview.
#
# 3. **Career Opportunities**: Being bilingual or multilingual can open up job opportunities and make you stand out in the global job market.
#
# 4. **Travel**: Makes traveling more enjoyable and immersive, allowing for better interaction with locals and understanding of the places you visit.
#
# 5. **Social Connections**: Enables you to meet new people and form connections with speakers of the language.
#
# 6. **Personal Satisfaction**: Achieving proficiency is a significant personal milestone and can boost confidence.
#
# To get started, consider using language learning apps, joining classes, engaging with native speakers through language exchange programs, or immersing yourself in media like movies and music in the target language. Patience and consistent practice are key!
# Assistant: What are some techniques to learn a new language effectively?
# Assistant: Learning a new language effectively involves a combination of techniques. Here are some methods that can help:
#
# 1. **Set Clear Goals**: Define why you want to learn the language and set achievable milestones.
#
# 2. **Use Language Apps**: Apps like Duolingo, Babbel, or Rosetta Stone offer structured learning and regular practice.
#
# 3. **Immerse Yourself**: Listen to music, watch movies, or read books in the target language to improve comprehension.
#
# 4. **Practice Speaking**: Engage in conversation with native speakers or language exchange partners to build speaking confidence.
#
# 5. **Take Classes**: Enroll in language courses online or in-person for structured learning and feedback.
#
# 6. **Flashcards and Vocabulary Lists**: Use tools like Anki or Quizlet to memorize vocabulary and phrases.
#
# 7. **Grammar Study**: Understand the grammatical structure through textbooks or online resources.
#
# 8. **Write Regularly**: Keep a journal or try writing essays to practice your writing skills.
#
# 9. **Consistency is Key**: Set aside regular time each day for focused study and practice.
#
# 10. **Be Patient and Persistent**: Language learning is a gradual process, so stay motivated and patient.
#
# Combining these methods can accelerate your language learning and make the process more enjoyable.
# Assistant: What are some effective techniques to learn a new language?
# Assistant: Learning a new language effectively involves diverse techniques. Here are some strategies to consider:
#
# 1. **Set Clear Goals**: Define specific, achievable milestones to stay motivated.
#
# 2. **Use Language Apps**: Apps like Duolingo, Babbel, and Rosetta Stone offer interactive and structured practice.
#
# 3. **Immerse Yourself**: Engage with media such as music, movies, and books in the target language to boost comprehension.
#
# 4. **Practice Speaking**: Converse with native speakers or language exchange partners to improve fluency and confidence.
#
# 5. **Enroll in Classes**: Consider online or in-person courses for structured learning and personalized feedback.
#
# 6. **Utilize Flashcards**: Use tools like Anki or Quizlet for vocabulary memorization and reinforcement.
#
# 7. **Study Grammar**: Understand and practice grammar rules through textbooks or online resources.
#
# 8. **Write Regularly**: Keep a journal or write short essays to enhance writing skills.
#
# 9. **Consistency**: Dedicate regular time each day for focused study and practice.
#
# 10. **Stay Patient and Persistent**: Progress takes time, so maintain motivation and patience throughout your learning journey.
#
# Combining these approaches can enhance the learning experience and help you achieve language proficiency.
